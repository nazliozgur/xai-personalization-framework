# %%
pip install black
# Out:
# ...
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.9 MB/s  0:00:001.8 MB/s eta 0:00:01
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [black]━━━━━ 3/4 [black]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Loading domain: All_Beauty
# Target sample size: 100,000
#   Progress: 25,000 rows read
#   Progress: 50,000 rows read
#   Progress: 75,000 rows read
# Loaded 100,000 rows | Columns: 11
#
# Loading domain: Gift_Cards
# Target sample size: 100,000
#   Progress: 25,000 rows read
#   Progress: 50,000 rows read
#   Progress: 75,000 rows read
# Loaded 100,000 rows | Columns: 11
#
# Loading domain: Digital_Music
# Target sample size: 100,000
# raw/review_categories/Digital_Music.json(…):   0%|          | 0.00/78.8M [00:00<?, ?B/s]
#   Progress: 25,000 rows read
#   Progress: 50,000 rows read
#   Progress: 75,000 rows read
# Loaded 100,000 rows | Columns: 11
#
# Successfully loaded domains: ['All_Beauty', 'Gift_Cards', 'Digital_Music']
